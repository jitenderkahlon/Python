# %% [markdown]
# # Python basics
#
# ### Notebook created by Jitender Kahlon
#
# ### Print()

# %%
# This is my first code
print ("hello I am Jitender2")
# Out:
# hello I am Jitender2

# %%
print ('"Hello"')
# Out:
# "Hello"

# %%
print ('"hello"')
# Out:
# "hello"

# %%
x = 'Hello'

# %%
x,y,z = 10,20,30
print(x)
print(y)
print(z)
print (x,y,z)
# Out:
# 10
# 20
# 30
# 10 20 30

# %% [markdown]
# ### Assignment Operators

# %%
# int  - integer 
x=10
print(type(x))
print(x)
# Out:
# <class 'int'>
# 10

# %%
# float 
x = 10.0
print(type(x))
print(x)
# Out:
# <class 'float'>
# 10.0

# %%
# Str - String
x = 'Jitender'
print(type(x))
print(x)
# Out:
# <class 'str'>
# Jitender

# %%
# Bool - Boolean 
x = True
print(type(x))
print(x)
# Out:
# <class 'bool'>
# True

# %% [markdown]
# ### Arithmetic Operators

# %%
x,y,z= 23,34,'Jitender'

# %%
#sum 
print(x+y)

# Difference 
print (x-y)

# Multiplication
print (x*y)

# Divide 
print (x/y)

# Quotient / 
print (x//y)

#Remainder/ Modulus
print (x%y)

# Exponential
print (2**3)
# Out:
# 57
# -11
# 782
# 0.6764705882352942
# 0
# 23
# 8

# %%
x,y,z
# Out:
# (23, 34, 'Jitender')

# %%
x = y+5
print (x)
# Out:
# 39

# %%
print(type(2+3j))
# Out:
# <class 'complex'>

# %%
a,b = 257, 257
a is b
# Out:
# True

# %%
a,b = 42, 42
print (id(a),id(b))
# Out:
# 140721697597640 140721697597640

# %% [markdown]
# ## Strings

# %%
x = 'Navneet'
y = 'kaur'

# %%
print(x+" "+y)
# Out:
# Navneet kaur

# %%
# String formatting
x = 'Priyanka'
y = 'Chandigarh'
print(f"Hello My name is {x} and I belong to {y}")
print ("Hello My name is", x, "and I belong to", y)
print ("I am {} and I live in {}".format(x,y))
# Out:
# Hello My name is Priyanka and I belong to Chandigarh
# Hello My name is Priyanka and I belong to Chandigarh
# I am Priyanka and I live in Chandigarh

# %%
name = 'Adarsh' 
len(name)
# Out:
# 6

# %%
x = 'Jitender'
len(x)
# Out:
# 8

# %%
x = 10 
x = str(x)
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'str'>

# %%
# Type Conversions
x = '10'
print(int(x))
# Out:
# 10

# %%
x = 23.68979
print(type(x))
int(x)
# Out:
# <class 'float'>
# 23

# %%
x = 12
float(x)
# Out:
# 12.0

# %%
x = "Jitender Singh"
print(x.lower())
# Out:
# jitender singh

# %%
x = "  Adarsh       "
len(x)
# Out:
# 15

# %%
print (len(x.strip()))
print (len(x.lstrip()))
print (len(x.rstrip()))
# Out:
# 6
# 13
# 8

# %%
x = "My name is Jitender Singh"
x.find("z")
x.replace("i", "2")
x.count("is ")
# Out:
# 1

# %%
x.startswith("My")
x.endswith("gh")
a = 'hello'
a.isalnum()
a.isalpha()
# Out:
# True

# %%
x = "India, is a Democratic, country"
print(x.split())
# Out:
# ['India,', 'is', 'a', 'Democratic,', 'country']

# %%
name = 'Adarsh'
city = 'Jalandhar'
print ("I am {} and I live in {}".format(name, city))
# Out:
# I am Adarsh and I live in Jalandhar

# %% [markdown]
# ## Conditional Logic

# %%
x = 9
if x>10:
    print ("X is greater than 10")
elif x<10 and x>5:
    print ("Value of X lies between 5 and 10")
else:
    print ("X is not greater than 10")
# Out:
# Value of X lies between 5 and 10

# %%
age = int(input("Enter your age"))
# Out:
# Enter your age 23

# %%
age = int(input("Enter your age"))

if age >=18:
    print ("Voter is eligible")
else:
    print ("Voter is not eligible")
# Out:
# Enter your age 23
# Voter is eligible
